# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Nima Sadeghi__
#
# I'm studying Industrial Engineering at Urmia University.

# %% [markdown]
# _I'm interested in data science because I have a keen mind in financial analysis and stock markets, and I intend to pursue financial engineering as a master's._

# %% [markdown]
# ### OK! My code is going to calculate my body's BMI.

# %%
my_hight = 1.89 #in meter
my_wight = 89 #kg

BMI = (my_wight/(my_hight*my_hight))

print("my BMI is " + str(BMI))
# Out:
# my BMI is 24.915315920606925

# %% [markdown]
# <a href="www.linkedin.com/in/nimasadeghi1999">My Linkedin Account</a>
#
#
# |Tital|Tital|Tital|
# |-----|-----|-----|
# |Cell|Cell|Cell|
# |Cell|Cell|Cell|
#
# - my Instagram acc:
#  - <a href="https://www.instagram.com/l_nima_sadeghi/">Instagram</a>
# - my Linkedin acc:
#  - <a href="www.linkedin.com/in/nimasadeghi1999">Linkedin</a>
# - my Twitter acc:
#  - <a href="https://twitter.com/L_Nima_Sadeghi">Twitter</a>
